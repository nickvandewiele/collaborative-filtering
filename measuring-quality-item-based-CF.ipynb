# %% [markdown]
# # Measuring the quality of recommender systems
#
# In this notebook, I explore how the quality of recommender systems can be measured.
#
# Recommender systems rely on predicting how users rate items.
#
# Based on the rating predictions, the recommender system recommends the items to a user with the highest predicted ratings.
#
# So, measuring the quality of a recommender system can be translated into measuring the predicted rating of an item against the real rating that a user gave. If the recommender predicts a 5-star rating when the true rating is 1-star, then that signals the quality of the predictions made by the recommender system is not that great.
#
# Some other principles of the general methodology to measure the quality:
# - ratings could be predicted for a set of (user, item) tuples. Aggregate metrics like __root mean square error__ (RMSE) are used to report the overall quality of the predictions.
# - rating predictions should be applied to an _unseen_ set of (user, item) observations. Otherwise, the prediction is trivial; the prediction could simply repeat the observation that the recommender had already seen. Hence, the dataset could be split into train / test sets, with the __train__ set shown to the recommender system, and the __test__ set used to report the quality of the recommender system.
# - Splitting the dataset into train / test could introduce unwanted __bias__. As a result, the metrics could not reflect the real quality of the recommender system. For example, if the train set only contains ratings of 1 and 2 stars, the recommender system may never be able to predict 5-star ratings. The dataset contains many more 4-star ratings than 1-star ratings. If we randomly sampled without taking this into account, we may end up under or overrepresenting certain x-star ratings. Hence, the train-test datasets are created by preserving the distribution of the ratings in both datasets. In other words, a __stratified__ split is applied.
#
# Some principles specific to measuring the quality of recommender systems based on __user-based collaborative filtering__:
# - __the test set cannot contain users that were not part of the train set__. This is because the algorithm searches the ratings dataset for the most similar users to the current user. If the current user is not part of the ratings dataset, finding the most similar users becomes impossible.
# - __the test set cannot contain items that were not part of the train set__. If the train set does not contain ratings of the item of other users, it becomes impossible to rate that specific item. This is because the predicted rating relies on the ratings of that specific item of other users.

# %%
# %load_ext autoreload
# %autoreload 2

# data manipulation
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt

import numpy as np

RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)

from item_based_collaborative_filtering import compute_similarities
from item_based_collaborative_filtering import predict
from utils import read_ratings

# %%
# paths to the files. download them from http://files.grouplens.org/datasets/movielens/ml-100k.zip if you don't have them yet
MOVIE_RATINGS_PATH = 'ml-100k/u.data'
MOVIE_NAMES_PATH = 'ml-100k/u.item'

# test sample size
TEST_SIZE = 0.01

# %%
ratings = read_ratings(MOVIE_RATINGS_PATH)
ratings = pd.DataFrame(data=ratings, columns=['user', 'movie', 'rating'])
ratings = ratings.astype(int)
ratings.head()
# Out:
#    user  movie  rating
# 0   196    242       3
# 1   186    302       3
# 2    22    377       1
# 3   244     51       2
# 4   166    346       1

# %% [markdown]
# # Train-test-split

# %%
# stratified to keep the distribution of movie ratings the same in train and test datasets.
train, test = train_test_split(
    ratings, 
    test_size=TEST_SIZE, 
    stratify=ratings.rating, 
    random_state=RANDOM_SEED
)

# %%
train.head()
# Out:
#        user  movie  rating
# 91378   882    151       5
# 89176   868    566       1
# 37540   194     91       3
# 2097    291    471       4
# 32223   334    221       5

# %%
train.rating.value_counts(normalize=True)
# Out:
# 4    0.341737
# 3    0.271455
# 5    0.212010
# 2    0.113697
# 1    0.061101
# Name: rating, dtype: float64

# %%
test.rating.value_counts(normalize=True)
# Out:
# 4    0.342
# 3    0.271
# 5    0.212
# 2    0.114
# 1    0.061
# Name: rating, dtype: float64

# %%
test.shape
# Out:
# (1000, 3)

# %%
# remove items from test set that are not part of train set
test = test.loc[test.movie.isin(train.movie)]
test.shape
# Out:
# (999, 3)

# %%
# test = test.sample(100)
test.head()
# Out:
#        user  movie  rating
# 8548    276    282       4
# 6687    180    421       5
# 93118   308    121       3
# 31373   428    243       4
# 79953   487    301       4

# %% [markdown]
# # Computing item-item similarities on the train data

# %%
# %%time
similarities = compute_similarities(train)
# Out:
# Wall time: 1min 21s

# %% [markdown]
# # Predicting the rating for a sample (user, item)

# %%
sample = ratings.sample(random_state=RANDOM_SEED)
user_id = sample.user.values[0]
item_id = sample.movie.values[0]

# %%
user_id, item_id
# Out:
# (877, 381)

# %%
predict(381, 12, train, similarities)
# Out:
# User 381 has rated 125 items.
# After removing movies that have not been rated by the user, we have 123 items.
# 4.4

# %% [markdown]
# # Rating predictions on the test set

# %%
# %%time
test['pred'] = test.apply(lambda row: predict(row.user, row.movie, train, similarities), axis=1)
# Out:
# User 276 has rated 509 items.
# After removing movies that have not been rated by the user, we have 483 items.
# User 180 has rated 61 items.
# After removing movies that have not been rated by the user, we have 61 items.
# User 308 has rated 392 items.
# After removing movies that have not been rated by the user, we have 387 items.
# User 428 has rated 54 items.
# After removing movies that have not been rated by the user, we have 51 items.
# User 487 has rated 228 items.
# After removing movies that have not been rated by the user, we have 221 items.
# User 552 has rated 83 items.
# After removing movies that have not been rated by the user, we have 82 items.
# User 55 has rated 20 items.
# After removing movies that have not been rated by the user, we have 20 items.
# User 1 has rated 269 items.
# After removing movies that have not been rated by the user, we have 262 items.
# User 407 has rated 223 items.
# After removing movies that have not been rated by the user, we have 223 items.
# User 788 has rated 246 items.
# After removing movies that have not been rated by the user, we have 239 items.
# User 194 has rated 301 items.
# After removing movies that have not been rated by the user, we have 297 items.
# User 368 has rated 44 items.
# After removing movies that have not been rated by the user, we have 43 items.
# User 401 has rated 149 items.
# After removing movies that have not been rated by the user, we have 148 items.
# User 704 has rated 89 items.
# After removing movies that have not been rated by the user, we have 84 items.
# User 125 has rated 179 items.
# After removing movies that have not been rated by the user, we have 168 items.
# User 174 has rated 172 items.
# After removing movies that have not been rated by the user, we have 155 items.
# User 276 has rated 509 items.
# After removing movies that have not been rated by the user, we have 164 items.
# User 505 has rated 109 items.
# After removing movies that have not been rated by the user, we have 107 items.
# User 795 has rated 153 items.
# After removing movies that have not been rated by the user, we have 151 items.
# User 514 has rated 192 items.
# After removing movies that have not been rated by the user, we have 190 items.
# User 489 has rated 107 items.
# After removing movies that have not been rated by the user, we have 92 items.
# User 897 has rated 184 items.
# After removing movies that have not been rated by the user, we have 183 items.
# User 782 has rated 230 items.
# After removing movies that have not been rated by the user, we have 113 items.
# User 504 has rated 249 items.
# After removing movies that have not been rated by the user, we have 236 items.
# User 614 has rated 38 items.
# After removing movies that have not been rated by the user, we have 36 items.
# User 198 has rated 179 items.
# After removing movies that have not been rated by the user, we have 174 items.
# User 837 has rated 45 items.
# After removing movies that have not been rated by the user, we have 45 items.
# User 92 has rated 383 items.
# After removing movies that have not been rated by the user, we have 362 items.
# User 191 has rated 26 items.
# After removing movies that have not been rated by the user, we have 25 items.
# User 416 has rated 487 items.
# After removing movies that have not been rated by the user, we have 477 items.
# User 334 has rated 327 items.
# After removing movies that have not been rated by the user, we have 267 items.
# User 23 has rated 148 items.
# After removing movies that have not been rated by the user, we have 146 items.
# User 385 has rated 277 items.
# After removing movies that have not been rated by the user, we have 249 items.
# User 642 has rated 312 items.
# After removing movies that have not been rated by the user, we have 260 items.
# User 332 has rated 179 items.
# After removing movies that have not been rated by the user, we have 173 items.
# User 487 has rated 228 items.
# After removing movies that have not been rated by the user, we have 225 items.
# User 82 has rated 165 items.
# After removing movies that have not been rated by the user, we have 162 items.
# User 442 has rated 142 items.
# After removing movies that have not been rated by the user, we have 142 items.
# User 325 has rated 141 items.
# After removing movies that have not been rated by the user, we have 138 items.
# User 643 has rated 202 items.
# After removing movies that have not been rated by the user, we have 199 items.
# User 374 has rated 267 items.
# After removing movies that have not been rated by the user, we have 246 items.
# User 58 has rated 151 items.
# After removing movies that have not been rated by the user, we have 75 items.
# User 286 has rated 285 items.
# After removing movies that have not been rated by the user, we have 262 items.
# User 146 has rated 28 items.
# After removing movies that have not been rated by the user, we have 25 items.
# User 558 has rated 19 items.
# After removing movies that have not been rated by the user, we have 19 items.
# User 934 has rated 169 items.
# After removing movies that have not been rated by the user, we have 152 items.
# User 885 has rated 101 items.
# After removing movies that have not been rated by the user, we have 101 items.
# User 308 has rated 392 items.
# After removing movies that have not been rated by the user, we have 386 items.
# User 77 has rated 69 items.
# After removing movies that have not been rated by the user, we have 69 items.
# User 270 has rated 134 items.
# After removing movies that have not been rated by the user, we have 132 items.
# User 99 has rated 134 items.
# After removing movies that have not been rated by the user, we have 132 items.
# User 792 has rated 46 items.
# After removing movies that have not been rated by the user, we have 45 items.
# User 621 has rated 169 items.
# After removing movies that have not been rated by the user, we have 169 items.
# User 360 has rated 101 items.
# After removing movies that have not been rated by the user, we have 101 items.
# User 606 has rated 231 items.
# After removing movies that have not been rated by the user, we have 227 items.
# User 498 has rated 148 items.
# After removing movies that have not been rated by the user, we have 142 items.
# User 90 has rated 294 items.
# After removing movies that have not been rated by the user, we have 258 items.
# User 809 has rated 19 items.
# After removing movies that have not been rated by the user, we have 19 items.
# User 44 has rated 149 items.
# After removing movies that have not been rated by the user, we have 149 items.
# User 327 has rated 282 items.
# After removing movies that have not been rated by the user, we have 280 items.
# User 342 has rated 198 items.
# After removing movies that have not been rated by the user, we have 184 items.
# User 406 has rated 336 items.
# After removing movies that have not been rated by the user, we have 297 items.
# User 932 has rated 237 items.
# After removing movies that have not been rated by the user, we have 211 items.
# User 495 has rated 208 items.
# After removing movies that have not been rated by the user, we have 207 items.
# User 624 has rated 139 items.
# After removing movies that have not been rated by the user, we have 126 items.
# User 715 has rated 165 items.
# After removing movies that have not been rated by the user, we have 165 items.
# User 397 has rated 101 items.
# After removing movies that have not been rated by the user, we have 93 items.
# User 425 has rated 202 items.
# After removing movies that have not been rated by the user, we have 195 items.
# User 911 has rated 95 items.
# After removing movies that have not been rated by the user, we have 95 items.
# User 336 has rated 129 items.
# After removing movies that have not been rated by the user, we have 127 items.
# User 545 has rated 160 items.
# After removing movies that have not been rated by the user, we have 160 items.
# User 763 has rated 126 items.
# After removing movies that have not been rated by the user, we have 122 items.
# User 398 has rated 171 items.
# After removing movies that have not been rated by the user, we have 167 items.
# User 758 has rated 351 items.
# After removing movies that have not been rated by the user, we have 343 items.
# User 54 has rated 64 items.
# After removing movies that have not been rated by the user, we have 64 items.
# User 760 has rated 40 items.
# After removing movies that have not been rated by the user, we have 32 items.
# User 770 has rated 63 items.
# After removing movies that have not been rated by the user, we have 62 items.
# User 417 has rated 363 items.
# After removing movies that have not been rated by the user, we have 243 items.
# User 567 has rated 153 items.
# After removing movies that have not been rated by the user, we have 152 items.
# User 488 has rated 152 items.
# After removing movies that have not been rated by the user, we have 149 items.
# User 374 has rated 267 items.
# After removing movies that have not been rated by the user, we have 238 items.
# User 495 has rated 208 items.
# After removing movies that have not been rated by the user, we have 206 items.
# User 458 has rated 180 items.
# After removing movies that have not been rated by the user, we have 177 items.
# User 551 has rated 327 items.
# After removing movies that have not been rated by the user, we have 178 items.
# User 11 has rated 179 items.
# After removing movies that have not been rated by the user, we have 178 items.
# User 125 has rated 179 items.
# After removing movies that have not been rated by the user, we have 170 items.
# User 124 has rated 23 items.
# After removing movies that have not been rated by the user, we have 23 items.
# User 308 has rated 392 items.
# After removing movies that have not been rated by the user, we have 383 items.
# User 347 has rated 197 items.
# After removing movies that have not been rated by the user, we have 196 items.
# User 201 has rated 382 items.
# After removing movies that have not been rated by the user, we have 357 items.
# User 606 has rated 231 items.
# After removing movies that have not been rated by the user, we have 226 items.
# User 100 has rated 57 items.
# After removing movies that have not been rated by the user, we have 51 items.
# User 943 has rated 166 items.
# After removing movies that have not been rated by the user, we have 165 items.
# User 7 has rated 399 items.
# After removing movies that have not been rated by the user, we have 377 items.
# User 499 has rated 99 items.
# After removing movies that have not been rated by the user, we have 98 items.
# User 518 has rated 71 items.
# After removing movies that have not been rated by the user, we have 70 items.
# User 5 has rated 174 items.
# After removing movies that have not been rated by the user, we have 166 items.
# User 436 has rated 142 items.
# After removing movies that have not been rated by the user, we have 134 items.
# User 835 has rated 100 items.
# After removing movies that have not been rated by the user, we have 98 items.
# User 437 has rated 258 items.
# After removing movies that have not been rated by the user, we have 253 items.
# User 280 has rated 252 items.
# After removing movies that have not been rated by the user, we have 243 items.
# User 765 has rated 22 items.
# After removing movies that have not been rated by the user, we have 22 items.
# User 13 has rated 634 items.
# After removing movies that have not been rated by the user, we have 470 items.
# User 551 has rated 327 items.
# After removing movies that have not been rated by the user, we have 318 items.
# User 936 has rated 140 items.
# After removing movies that have not been rated by the user, we have 125 items.
# User 29 has rated 33 items.
# After removing movies that have not been rated by the user, we have 33 items.
# User 267 has rated 184 items.
# After removing movies that have not been rated by the user, we have 183 items.
# User 363 has rated 307 items.
# After removing movies that have not been rated by the user, we have 300 items.
# User 178 has rated 268 items.
# After removing movies that have not been rated by the user, we have 262 items.
# User 213 has rated 125 items.
# After removing movies that have not been rated by the user, we have 125 items.
# User 663 has rated 156 items.
# After removing movies that have not been rated by the user, we have 154 items.
# User 70 has rated 130 items.
# After removing movies that have not been rated by the user, we have 129 items.
# User 892 has rated 222 items.
# After removing movies that have not been rated by the user, we have 219 items.
# User 633 has rated 55 items.
# After removing movies that have not been rated by the user, we have 55 items.
# User 175 has rated 37 items.
# After removing movies that have not been rated by the user, we have 37 items.
# User 60 has rated 207 items.
# After removing movies that have not been rated by the user, we have 192 items.
# User 886 has rated 238 items.
# After removing movies that have not been rated by the user, we have 229 items.
# User 715 has rated 165 items.
# After removing movies that have not been rated by the user, we have 164 items.
# User 923 has rated 72 items.
# After removing movies that have not been rated by the user, we have 72 items.
# User 406 has rated 336 items.
# After removing movies that have not been rated by the user, we have 329 items.
# User 862 has rated 162 items.
# After removing movies that have not been rated by the user, we have 144 items.
# User 894 has rated 243 items.
# After removing movies that have not been rated by the user, we have 215 items.
# User 305 has rated 220 items.
# After removing movies that have not been rated by the user, we have 209 items.
# User 741 has rated 103 items.
# After removing movies that have not been rated by the user, we have 98 items.
# User 221 has rated 145 items.
# After removing movies that have not been rated by the user, we have 144 items.
# User 326 has rated 183 items.
# After removing movies that have not been rated by the user, we have 180 items.
# User 698 has rated 126 items.
# After removing movies that have not been rated by the user, we have 124 items.
# User 130 has rated 350 items.
# After removing movies that have not been rated by the user, we have 327 items.
# User 181 has rated 433 items.
# After removing movies that have not been rated by the user, we have 318 items.
# User 825 has rated 142 items.
# After removing movies that have not been rated by the user, we have 137 items.
# User 699 has rated 147 items.
# After removing movies that have not been rated by the user, we have 53 items.
# User 497 has rated 277 items.
# After removing movies that have not been rated by the user, we have 275 items.
# User 798 has rated 236 items.
# After removing movies that have not been rated by the user, we have 209 items.
# User 280 has rated 252 items.
# After removing movies that have not been rated by the user, we have 247 items.
# User 654 has rated 145 items.
# After removing movies that have not been rated by the user, we have 143 items.
# User 537 has rated 488 items.
# After removing movies that have not been rated by the user, we have 468 items.
# User 113 has rated 50 items.
# After removing movies that have not been rated by the user, we have 47 items.
# User 405 has rated 731 items.
# After removing movies that have not been rated by the user, we have 456 items.
# User 276 has rated 509 items.
# After removing movies that have not been rated by the user, we have 387 items.
# User 923 has rated 72 items.
# After removing movies that have not been rated by the user, we have 69 items.
# User 939 has rated 47 items.
# After removing movies that have not been rated by the user, we have 42 items.
# User 671 has rated 123 items.
# After removing movies that have not been rated by the user, we have 120 items.
# User 633 has rated 55 items.
# After removing movies that have not been rated by the user, we have 54 items.
# User 279 has rated 431 items.
# After removing movies that have not been rated by the user, we have 280 items.
# User 749 has rated 301 items.
# After removing movies that have not been rated by the user, we have 275 items.
# User 156 has rated 36 items.
# After removing movies that have not been rated by the user, we have 36 items.
# User 243 has rated 80 items.
# After removing movies that have not been rated by the user, we have 76 items.
# User 902 has rated 46 items.
# After removing movies that have not been rated by the user, we have 46 items.
# User 543 has rated 194 items.
# After removing movies that have not been rated by the user, we have 190 items.
# User 167 has rated 68 items.
# After removing movies that have not been rated by the user, we have 57 items.
# User 767 has rated 36 items.
# After removing movies that have not been rated by the user, we have 35 items.
# User 932 has rated 237 items.
# After removing movies that have not been rated by the user, we have 202 items.
# User 749 has rated 301 items.
# After removing movies that have not been rated by the user, we have 288 items.
# User 907 has rated 144 items.
# After removing movies that have not been rated by the user, we have 138 items.
# User 880 has rated 363 items.
# After removing movies that have not been rated by the user, we have 344 items.
# User 548 has rated 153 items.
# After removing movies that have not been rated by the user, we have 152 items.
# User 43 has rated 220 items.
# After removing movies that have not been rated by the user, we have 207 items.
# User 927 has rated 119 items.
# After removing movies that have not been rated by the user, we have 115 items.
# User 151 has rated 303 items.
# After removing movies that have not been rated by the user, we have 290 items.
# User 338 has rated 74 items.
# After removing movies that have not been rated by the user, we have 73 items.
# User 703 has rated 46 items.
# After removing movies that have not been rated by the user, we have 46 items.
# User 916 has rated 315 items.
# After removing movies that have not been rated by the user, we have 288 items.
# User 280 has rated 252 items.
# After removing movies that have not been rated by the user, we have 242 items.
# User 222 has rated 382 items.
# After removing movies that have not been rated by the user, we have 370 items.
# User 502 has rated 36 items.
# After removing movies that have not been rated by the user, we have 35 items.
# User 500 has rated 222 items.
# After removing movies that have not been rated by the user, we have 214 items.
# User 92 has rated 383 items.
# After removing movies that have not been rated by the user, we have 356 items.
# User 14 has rated 96 items.
# After removing movies that have not been rated by the user, we have 94 items.
# User 650 has rated 309 items.
# After removing movies that have not been rated by the user, we have 302 items.
# User 527 has rated 136 items.
# After removing movies that have not been rated by the user, we have 118 items.
# User 452 has rated 204 items.
# After removing movies that have not been rated by the user, we have 191 items.
# User 641 has rated 37 items.
# After removing movies that have not been rated by the user, we have 37 items.
# User 751 has rated 166 items.
# After removing movies that have not been rated by the user, we have 160 items.
# User 349 has rated 39 items.
# After removing movies that have not been rated by the user, we have 39 items.
# User 374 has rated 267 items.
# After removing movies that have not been rated by the user, we have 262 items.
# User 457 has rated 275 items.
# After removing movies that have not been rated by the user, we have 266 items.
# User 769 has rated 28 items.
# After removing movies that have not been rated by the user, we have 26 items.
# User 300 has rated 18 items.
# After removing movies that have not been rated by the user, we have 18 items.
# User 766 has rated 174 items.
# After removing movies that have not been rated by the user, we have 169 items.
# User 376 has rated 29 items.
# After removing movies that have not been rated by the user, we have 29 items.
# User 795 has rated 153 items.
# After removing movies that have not been rated by the user, we have 151 items.
# User 795 has rated 153 items.
# After removing movies that have not been rated by the user, we have 148 items.
# User 72 has rated 135 items.
# After removing movies that have not been rated by the user, we have 133 items.
# User 603 has rated 46 items.
# After removing movies that have not been rated by the user, we have 45 items.
# User 446 has rated 35 items.
# After removing movies that have not been rated by the user, we have 32 items.
# User 276 has rated 509 items.
# After removing movies that have not been rated by the user, we have 487 items.
# User 883 has rated 265 items.
# After removing movies that have not been rated by the user, we have 243 items.
# User 918 has rated 102 items.
# After removing movies that have not been rated by the user, we have 14 items.
# User 49 has rated 214 items.
# After removing movies that have not been rated by the user, we have 173 items.
# User 731 has rated 81 items.
# After removing movies that have not been rated by the user, we have 77 items.
# User 445 has rated 132 items.
# After removing movies that have not been rated by the user, we have 126 items.
# User 79 has rated 53 items.
# After removing movies that have not been rated by the user, we have 53 items.
# User 815 has rated 181 items.
# After removing movies that have not been rated by the user, we have 180 items.
# User 193 has rated 120 items.
# After removing movies that have not been rated by the user, we have 111 items.
# User 654 has rated 145 items.
# After removing movies that have not been rated by the user, we have 145 items.
# User 598 has rated 24 items.
# After removing movies that have not been rated by the user, we have 24 items.
# User 315 has rated 86 items.
# After removing movies that have not been rated by the user, we have 86 items.
# User 483 has rated 57 items.
# After removing movies that have not been rated by the user, we have 56 items.
# User 445 has rated 132 items.
# After removing movies that have not been rated by the user, we have 122 items.
# User 617 has rated 106 items.
# After removing movies that have not been rated by the user, we have 100 items.
# User 606 has rated 231 items.
# After removing movies that have not been rated by the user, we have 225 items.
# User 406 has rated 336 items.
# After removing movies that have not been rated by the user, we have 316 items.
# User 642 has rated 312 items.
# After removing movies that have not been rated by the user, we have 278 items.
# User 796 has rated 352 items.
# After removing movies that have not been rated by the user, we have 312 items.
# User 601 has rated 144 items.
# After removing movies that have not been rated by the user, we have 143 items.
# User 348 has rated 57 items.
# After removing movies that have not been rated by the user, we have 55 items.
# User 543 has rated 194 items.
# After removing movies that have not been rated by the user, we have 186 items.
# User 660 has rated 221 items.
# After removing movies that have not been rated by the user, we have 221 items.
# User 280 has rated 252 items.
# After removing movies that have not been rated by the user, we have 244 items.
# User 48 has rated 65 items.
# After removing movies that have not been rated by the user, we have 60 items.
# User 405 has rated 731 items.
# After removing movies that have not been rated by the user, we have 0 items.
# User 332 has rated 179 items.
# After removing movies that have not been rated by the user, we have 179 items.
# User 165 has rated 29 items.
# After removing movies that have not been rated by the user, we have 29 items.
# User 627 has rated 177 items.
# After removing movies that have not been rated by the user, we have 176 items.
# User 276 has rated 509 items.
# After removing movies that have not been rated by the user, we have 488 items.
# User 625 has rated 104 items.
# After removing movies that have not been rated by the user, we have 104 items.
# User 102 has rated 214 items.
# After removing movies that have not been rated by the user, we have 213 items.
# User 286 has rated 285 items.
# After removing movies that have not been rated by the user, we have 237 items.
# User 450 has rated 534 items.
# After removing movies that have not been rated by the user, we have 456 items.
# User 298 has rated 122 items.
# After removing movies that have not been rated by the user, we have 121 items.
# User 25 has rated 77 items.
# After removing movies that have not been rated by the user, we have 77 items.
# User 226 has rated 49 items.
# After removing movies that have not been rated by the user, we have 49 items.
# User 409 has rated 201 items.
# After removing movies that have not been rated by the user, we have 175 items.
# User 90 has rated 294 items.
# After removing movies that have not been rated by the user, we have 283 items.
# User 823 has rated 183 items.
# After removing movies that have not been rated by the user, we have 183 items.
# User 177 has rated 112 items.
# After removing movies that have not been rated by the user, we have 112 items.
# User 188 has rated 109 items.
# After removing movies that have not been rated by the user, we have 108 items.
# User 550 has rated 39 items.
# After removing movies that have not been rated by the user, we have 38 items.
# User 445 has rated 132 items.
# After removing movies that have not been rated by the user, we have 122 items.
# User 109 has rated 231 items.
# After removing movies that have not been rated by the user, we have 228 items.
# User 669 has rated 98 items.
# After removing movies that have not been rated by the user, we have 97 items.
# User 854 has rated 213 items.
# After removing movies that have not been rated by the user, we have 206 items.
# User 641 has rated 37 items.
# After removing movies that have not been rated by the user, we have 37 items.
# User 790 has rated 228 items.
# After removing movies that have not been rated by the user, we have 226 items.
# User 234 has rated 474 items.
# After removing movies that have not been rated by the user, we have 361 items.
# User 586 has rated 162 items.
# After removing movies that have not been rated by the user, we have 160 items.
# User 735 has rated 51 items.
# After removing movies that have not been rated by the user, we have 51 items.
# User 524 has rated 301 items.
# After removing movies that have not been rated by the user, we have 271 items.
# User 751 has rated 166 items.
# After removing movies that have not been rated by the user, we have 159 items.
# User 942 has rated 77 items.
# After removing movies that have not been rated by the user, we have 62 items.
# User 721 has rated 166 items.
# After removing movies that have not been rated by the user, we have 120 items.
# User 384 has rated 21 items.
# After removing movies that have not been rated by the user, we have 21 items.
# User 151 has rated 303 items.
# After removing movies that have not been rated by the user, we have 299 items.
# User 896 has rated 356 items.
# After removing movies that have not been rated by the user, we have 320 items.
# User 896 has rated 356 items.
# After removing movies that have not been rated by the user, we have 348 items.
# User 244 has rated 237 items.
# After removing movies that have not been rated by the user, we have 224 items.
# User 655 has rated 677 items.
# After removing movies that have not been rated by the user, we have 312 items.
# User 222 has rated 382 items.
# After removing movies that have not been rated by the user, we have 376 items.
# User 454 has rated 232 items.
# After removing movies that have not been rated by the user, we have 31 items.
# User 264 has rated 117 items.
# After removing movies that have not been rated by the user, we have 110 items.
# User 874 has rated 32 items.
# After removing movies that have not been rated by the user, we have 32 items.
# User 15 has rated 103 items.
# After removing movies that have not been rated by the user, we have 95 items.
# User 536 has rated 161 items.
# After removing movies that have not been rated by the user, we have 159 items.
# User 22 has rated 127 items.
# After removing movies that have not been rated by the user, we have 125 items.
# User 655 has rated 677 items.
# After removing movies that have not been rated by the user, we have 0 items.
# User 218 has rated 51 items.
# After removing movies that have not been rated by the user, we have 50 items.
# User 63 has rated 92 items.
# After removing movies that have not been rated by the user, we have 91 items.
# User 318 has rated 171 items.
# After removing movies that have not been rated by the user, we have 170 items.
# User 395 has rated 55 items.
# After removing movies that have not been rated by the user, we have 55 items.
# User 393 has rated 444 items.
# After removing movies that have not been rated by the user, we have 426 items.
# User 247 has rated 25 items.
# After removing movies that have not been rated by the user, we have 25 items.
# User 860 has rated 69 items.
# After removing movies that have not been rated by the user, we have 64 items.
# User 56 has rated 182 items.
# After removing movies that have not been rated by the user, we have 182 items.
# User 666 has rated 243 items.
# After removing movies that have not been rated by the user, we have 242 items.
# User 318 has rated 171 items.
# After removing movies that have not been rated by the user, we have 141 items.
# User 425 has rated 202 items.
# After removing movies that have not been rated by the user, we have 178 items.
# User 669 has rated 98 items.
# After removing movies that have not been rated by the user, we have 97 items.
# User 518 has rated 71 items.
# After removing movies that have not been rated by the user, we have 70 items.
# User 601 has rated 144 items.
# After removing movies that have not been rated by the user, we have 118 items.
# User 313 has rated 255 items.
# After removing movies that have not been rated by the user, we have 251 items.
# User 506 has rated 241 items.
# After removing movies that have not been rated by the user, we have 239 items.
# User 548 has rated 153 items.
# After removing movies that have not been rated by the user, we have 152 items.
# User 798 has rated 236 items.
# After removing movies that have not been rated by the user, we have 154 items.
# User 109 has rated 231 items.
# After removing movies that have not been rated by the user, we have 228 items.
# User 460 has rated 66 items.
# After removing movies that have not been rated by the user, we have 32 items.
# User 401 has rated 149 items.
# After removing movies that have not been rated by the user, we have 144 items.
# User 648 has rated 295 items.
# After removing movies that have not been rated by the user, we have 279 items.
# User 893 has rated 57 items.
# After removing movies that have not been rated by the user, we have 55 items.
# User 495 has rated 208 items.
# After removing movies that have not been rated by the user, we have 202 items.
# User 733 has rated 106 items.
# After removing movies that have not been rated by the user, we have 52 items.
# User 846 has rated 401 items.
# After removing movies that have not been rated by the user, we have 376 items.
# User 559 has rated 74 items.
# After removing movies that have not been rated by the user, we have 70 items.
# User 116 has rated 141 items.
# After removing movies that have not been rated by the user, we have 111 items.
# User 846 has rated 401 items.
# After removing movies that have not been rated by the user, we have 378 items.
# User 648 has rated 295 items.
# After removing movies that have not been rated by the user, we have 284 items.
# User 264 has rated 117 items.
# After removing movies that have not been rated by the user, we have 113 items.
# User 454 has rated 232 items.
# After removing movies that have not been rated by the user, we have 228 items.
# User 246 has rated 194 items.
# After removing movies that have not been rated by the user, we have 192 items.
# User 239 has rated 157 items.
# After removing movies that have not been rated by the user, we have 146 items.
# User 795 has rated 153 items.
# After removing movies that have not been rated by the user, we have 150 items.
# User 939 has rated 47 items.
# After removing movies that have not been rated by the user, we have 31 items.
# User 911 has rated 95 items.
# After removing movies that have not been rated by the user, we have 94 items.
# User 6 has rated 209 items.
# After removing movies that have not been rated by the user, we have 200 items.
# User 224 has rated 138 items.
# After removing movies that have not been rated by the user, we have 123 items.
# User 300 has rated 18 items.
# After removing movies that have not been rated by the user, we have 14 items.
# User 334 has rated 327 items.
# After removing movies that have not been rated by the user, we have 312 items.
# User 628 has rated 26 items.
# After removing movies that have not been rated by the user, we have 23 items.
# User 210 has rated 131 items.
# After removing movies that have not been rated by the user, we have 129 items.
# User 354 has rated 232 items.
# After removing movies that have not been rated by the user, we have 127 items.
# User 508 has rated 85 items.
# After removing movies that have not been rated by the user, we have 85 items.
# User 594 has rated 24 items.
# After removing movies that have not been rated by the user, we have 24 items.
# User 896 has rated 356 items.
# After removing movies that have not been rated by the user, we have 350 items.
# User 682 has rated 397 items.
# After removing movies that have not been rated by the user, we have 350 items.
# User 697 has rated 104 items.
# After removing movies that have not been rated by the user, we have 96 items.
# User 642 has rated 312 items.
# After removing movies that have not been rated by the user, we have 272 items.
# User 110 has rated 132 items.
# After removing movies that have not been rated by the user, we have 131 items.
# User 206 has rated 62 items.
# After removing movies that have not been rated by the user, we have 33 items.
# User 860 has rated 69 items.
# After removing movies that have not been rated by the user, we have 45 items.
# User 647 has rated 56 items.
# After removing movies that have not been rated by the user, we have 56 items.
# User 676 has rated 76 items.
# After removing movies that have not been rated by the user, we have 70 items.
# User 457 has rated 275 items.
# After removing movies that have not been rated by the user, we have 266 items.
# User 578 has rated 23 items.
# After removing movies that have not been rated by the user, we have 21 items.
# User 304 has rated 25 items.
# After removing movies that have not been rated by the user, we have 23 items.
# User 378 has rated 373 items.
# After removing movies that have not been rated by the user, we have 362 items.
# User 201 has rated 382 items.
# After removing movies that have not been rated by the user, we have 264 items.
# User 286 has rated 285 items.
# After removing movies that have not been rated by the user, we have 199 items.
# User 786 has rated 115 items.
# After removing movies that have not been rated by the user, we have 115 items.
# User 450 has rated 534 items.
# After removing movies that have not been rated by the user, we have 469 items.
# User 678 has rated 27 items.
# After removing movies that have not been rated by the user, we have 27 items.
# User 655 has rated 677 items.
# After removing movies that have not been rated by the user, we have 454 items.
# User 292 has rated 122 items.
# After removing movies that have not been rated by the user, we have 122 items.
# User 234 has rated 474 items.
# After removing movies that have not been rated by the user, we have 389 items.
# User 846 has rated 401 items.
# After removing movies that have not been rated by the user, we have 354 items.
# User 250 has rated 121 items.
# After removing movies that have not been rated by the user, we have 118 items.
# User 622 has rated 226 items.
# After removing movies that have not been rated by the user, we have 208 items.
# User 796 has rated 352 items.
# After removing movies that have not been rated by the user, we have 306 items.
# User 825 has rated 142 items.
# After removing movies that have not been rated by the user, we have 136 items.
# User 507 has rated 56 items.
# After removing movies that have not been rated by the user, we have 55 items.
# User 680 has rated 37 items.
# After removing movies that have not been rated by the user, we have 37 items.
# User 545 has rated 160 items.
# After removing movies that have not been rated by the user, we have 160 items.
# User 316 has rated 73 items.
# After removing movies that have not been rated by the user, we have 72 items.
# User 223 has rated 103 items.
# After removing movies that have not been rated by the user, we have 91 items.
# User 735 has rated 51 items.
# After removing movies that have not been rated by the user, we have 51 items.
# User 232 has rated 91 items.
# After removing movies that have not been rated by the user, we have 91 items.
# User 795 has rated 153 items.
# After removing movies that have not been rated by the user, we have 152 items.
# User 818 has rated 20 items.
# After removing movies that have not been rated by the user, we have 18 items.
# User 878 has rated 133 items.
# After removing movies that have not been rated by the user, we have 131 items.
# User 881 has rated 256 items.
# After removing movies that have not been rated by the user, we have 239 items.
# User 880 has rated 363 items.
# After removing movies that have not been rated by the user, we have 257 items.
# User 26 has rated 105 items.
# After removing movies that have not been rated by the user, we have 103 items.
# User 892 has rated 222 items.
# After removing movies that have not been rated by the user, we have 196 items.
# User 796 has rated 352 items.
# After removing movies that have not been rated by the user, we have 348 items.
# User 334 has rated 327 items.
# After removing movies that have not been rated by the user, we have 301 items.
# User 174 has rated 172 items.
# After removing movies that have not been rated by the user, we have 168 items.
# User 757 has rated 165 items.
# After removing movies that have not been rated by the user, we have 165 items.
# User 114 has rated 47 items.
# After removing movies that have not been rated by the user, we have 46 items.
# User 621 has rated 169 items.
# After removing movies that have not been rated by the user, we have 129 items.
# User 233 has rated 108 items.
# After removing movies that have not been rated by the user, we have 108 items.
# User 32 has rated 40 items.
# After removing movies that have not been rated by the user, we have 40 items.
# User 899 has rated 133 items.
# After removing movies that have not been rated by the user, we have 133 items.
# User 178 has rated 268 items.
# After removing movies that have not been rated by the user, we have 240 items.
# User 627 has rated 177 items.
# After removing movies that have not been rated by the user, we have 170 items.
# User 460 has rated 66 items.
# After removing movies that have not been rated by the user, we have 65 items.
# User 593 has rated 154 items.
# After removing movies that have not been rated by the user, we have 154 items.
# User 436 has rated 142 items.
# After removing movies that have not been rated by the user, we have 124 items.
# User 579 has rated 73 items.
# After removing movies that have not been rated by the user, we have 72 items.
# User 796 has rated 352 items.
# After removing movies that have not been rated by the user, we have 349 items.
# User 303 has rated 477 items.
# After removing movies that have not been rated by the user, we have 235 items.
# User 902 has rated 46 items.
# After removing movies that have not been rated by the user, we have 46 items.
# User 942 has rated 77 items.
# After removing movies that have not been rated by the user, we have 76 items.
# User 901 has rated 119 items.
# After removing movies that have not been rated by the user, we have 116 items.
# User 118 has rated 70 items.
# After removing movies that have not been rated by the user, we have 69 items.
# User 214 has rated 127 items.
# After removing movies that have not been rated by the user, we have 127 items.
# User 537 has rated 488 items.
# After removing movies that have not been rated by the user, we have 460 items.
# User 533 has rated 258 items.
# After removing movies that have not been rated by the user, we have 256 items.
# User 930 has rated 62 items.
# After removing movies that have not been rated by the user, we have 62 items.
# User 637 has rated 101 items.
# After removing movies that have not been rated by the user, we have 9 items.
# User 90 has rated 294 items.
# After removing movies that have not been rated by the user, we have 255 items.
# User 758 has rated 351 items.
# After removing movies that have not been rated by the user, we have 337 items.
# User 297 has rated 189 items.
# After removing movies that have not been rated by the user, we have 186 items.
# User 298 has rated 122 items.
# After removing movies that have not been rated by the user, we have 119 items.
# User 301 has rated 274 items.
# After removing movies that have not been rated by the user, we have 270 items.
# User 391 has rated 118 items.
# After removing movies that have not been rated by the user, we have 118 items.
# User 391 has rated 118 items.
# After removing movies that have not been rated by the user, we have 118 items.
# User 401 has rated 149 items.
# After removing movies that have not been rated by the user, we have 145 items.
# User 437 has rated 258 items.
# After removing movies that have not been rated by the user, we have 163 items.
# User 854 has rated 213 items.
# After removing movies that have not been rated by the user, we have 208 items.
# User 313 has rated 255 items.
# After removing movies that have not been rated by the user, we have 252 items.
# User 869 has rated 45 items.
# After removing movies that have not been rated by the user, we have 0 items.
# User 291 has rated 293 items.
# After removing movies that have not been rated by the user, we have 181 items.
# User 477 has rated 34 items.
# After removing movies that have not been rated by the user, we have 34 items.
# User 390 has rated 30 items.
# After removing movies that have not been rated by the user, we have 30 items.
# User 287 has rated 60 items.
# After removing movies that have not been rated by the user, we have 60 items.
# User 274 has rated 70 items.
# After removing movies that have not been rated by the user, we have 70 items.
# User 896 has rated 356 items.
# After removing movies that have not been rated by the user, we have 336 items.
# User 468 has rated 141 items.
# After removing movies that have not been rated by the user, we have 141 items.
# User 937 has rated 39 items.
# After removing movies that have not been rated by the user, we have 39 items.
# User 178 has rated 268 items.
# After removing movies that have not been rated by the user, we have 248 items.
# User 89 has rated 72 items.
# After removing movies that have not been rated by the user, we have 72 items.
# User 560 has rated 98 items.
# After removing movies that have not been rated by the user, we have 87 items.
# User 51 has rated 22 items.
# After removing movies that have not been rated by the user, we have 22 items.
# User 85 has rated 287 items.
# After removing movies that have not been rated by the user, we have 247 items.
# User 392 has rated 109 items.
# After removing movies that have not been rated by the user, we have 88 items.
# User 188 has rated 109 items.
# After removing movies that have not been rated by the user, we have 108 items.
# User 77 has rated 69 items.
# After removing movies that have not been rated by the user, we have 69 items.
# User 378 has rated 373 items.
# After removing movies that have not been rated by the user, we have 360 items.
# User 458 has rated 180 items.
# After removing movies that have not been rated by the user, we have 178 items.
# User 174 has rated 172 items.
# After removing movies that have not been rated by the user, we have 158 items.
# User 870 has rated 265 items.
# After removing movies that have not been rated by the user, we have 257 items.
# User 848 has rated 149 items.
# After removing movies that have not been rated by the user, we have 147 items.
# User 298 has rated 122 items.
# After removing movies that have not been rated by the user, we have 121 items.
# User 361 has rated 119 items.
# After removing movies that have not been rated by the user, we have 118 items.
# User 7 has rated 399 items.
# After removing movies that have not been rated by the user, we have 386 items.
# User 334 has rated 327 items.
# After removing movies that have not been rated by the user, we have 319 items.
# User 533 has rated 258 items.
# After removing movies that have not been rated by the user, we have 252 items.
# User 893 has rated 57 items.
# After removing movies that have not been rated by the user, we have 57 items.
# User 271 has rated 277 items.
# After removing movies that have not been rated by the user, we have 271 items.
# User 710 has rated 84 items.
# After removing movies that have not been rated by the user, we have 84 items.
# User 722 has rated 41 items.
# After removing movies that have not been rated by the user, we have 41 items.
# User 26 has rated 105 items.
# After removing movies that have not been rated by the user, we have 104 items.
# User 627 has rated 177 items.
# After removing movies that have not been rated by the user, we have 176 items.
# User 618 has rated 214 items.
# After removing movies that have not been rated by the user, we have 212 items.
# User 587 has rated 96 items.
# After removing movies that have not been rated by the user, we have 91 items.
# User 870 has rated 265 items.
# After removing movies that have not been rated by the user, we have 201 items.
# User 805 has rated 268 items.
# After removing movies that have not been rated by the user, we have 241 items.
# User 11 has rated 179 items.
# After removing movies that have not been rated by the user, we have 179 items.
# User 270 has rated 134 items.
# After removing movies that have not been rated by the user, we have 131 items.
# User 316 has rated 73 items.
# After removing movies that have not been rated by the user, we have 73 items.
# User 370 has rated 74 items.
# After removing movies that have not been rated by the user, we have 73 items.
# User 689 has rated 35 items.
# After removing movies that have not been rated by the user, we have 35 items.
# User 749 has rated 301 items.
# After removing movies that have not been rated by the user, we have 299 items.
# User 339 has rated 252 items.
# After removing movies that have not been rated by the user, we have 249 items.
# User 81 has rated 57 items.
# After removing movies that have not been rated by the user, we have 56 items.
# User 320 has rated 152 items.
# After removing movies that have not been rated by the user, we have 150 items.
# User 611 has rated 40 items.
# After removing movies that have not been rated by the user, we have 39 items.
# User 256 has rated 205 items.
# After removing movies that have not been rated by the user, we have 163 items.
# User 374 has rated 267 items.
# After removing movies that have not been rated by the user, we have 185 items.
# User 201 has rated 382 items.
# After removing movies that have not been rated by the user, we have 0 items.
# User 194 has rated 301 items.
# After removing movies that have not been rated by the user, we have 286 items.
# User 257 has rated 56 items.
# After removing movies that have not been rated by the user, we have 17 items.
# User 684 has rated 84 items.
# After removing movies that have not been rated by the user, we have 83 items.
# User 308 has rated 392 items.
# After removing movies that have not been rated by the user, we have 385 items.
# User 551 has rated 327 items.
# After removing movies that have not been rated by the user, we have 316 items.
# User 763 has rated 126 items.
# After removing movies that have not been rated by the user, we have 53 items.
# User 321 has rated 124 items.
# After removing movies that have not been rated by the user, we have 123 items.
# User 693 has rated 151 items.
# After removing movies that have not been rated by the user, we have 149 items.
# User 727 has rated 319 items.
# After removing movies that have not been rated by the user, we have 316 items.
# User 524 has rated 301 items.
# After removing movies that have not been rated by the user, we have 278 items.
# User 352 has rated 41 items.
# After removing movies that have not been rated by the user, we have 41 items.
# User 92 has rated 383 items.
# After removing movies that have not been rated by the user, we have 356 items.
# User 450 has rated 534 items.
# After removing movies that have not been rated by the user, we have 382 items.
# User 639 has rated 147 items.
# After removing movies that have not been rated by the user, we have 146 items.
# User 269 has rated 319 items.
# After removing movies that have not been rated by the user, we have 311 items.
# User 479 has rated 200 items.
# ...
# User 843 has rated 203 items.
# After removing movies that have not been rated by the user, we have 201 items.
# User 524 has rated 301 items.
# After removing movies that have not been rated by the user, we have 293 items.
# User 590 has rated 45 items.
# After removing movies that have not been rated by the user, we have 44 items.
# User 217 has rated 74 items.
# After removing movies that have not been rated by the user, we have 74 items.
# User 292 has rated 122 items.
# After removing movies that have not been rated by the user, we have 122 items.
# User 223 has rated 103 items.
# After removing movies that have not been rated by the user, we have 100 items.
# User 410 has rated 27 items.
# After removing movies that have not been rated by the user, we have 27 items.
# User 660 has rated 221 items.
# After removing movies that have not been rated by the user, we have 210 items.
# User 83 has rated 152 items.
# After removing movies that have not been rated by the user, we have 144 items.
# User 276 has rated 509 items.
# After removing movies that have not been rated by the user, we have 474 items.
# User 392 has rated 109 items.
# After removing movies that have not been rated by the user, we have 107 items.
# User 205 has rated 21 items.
# After removing movies that have not been rated by the user, we have 21 items.
# User 248 has rated 55 items.
# After removing movies that have not been rated by the user, we have 55 items.
# User 758 has rated 351 items.
# After removing movies that have not been rated by the user, we have 341 items.
# User 251 has rated 75 items.
# After removing movies that have not been rated by the user, we have 74 items.
# User 889 has rated 323 items.
# After removing movies that have not been rated by the user, we have 294 items.
# User 521 has rated 148 items.
# After removing movies that have not been rated by the user, we have 146 items.
# User 907 has rated 144 items.
# After removing movies that have not been rated by the user, we have 141 items.
# User 535 has rated 217 items.
# After removing movies that have not been rated by the user, we have 215 items.
# User 932 has rated 237 items.
# After removing movies that have not been rated by the user, we have 213 items.
# User 308 has rated 392 items.
# After removing movies that have not been rated by the user, we have 381 items.
# User 295 has rated 194 items.
# After removing movies that have not been rated by the user, we have 192 items.
# User 870 has rated 265 items.
# After removing movies that have not been rated by the user, we have 240 items.
# User 493 has rated 133 items.
# After removing movies that have not been rated by the user, we have 122 items.
# User 178 has rated 268 items.
# After removing movies that have not been rated by the user, we have 265 items.
# User 95 has rated 275 items.
# After removing movies that have not been rated by the user, we have 271 items.
# User 889 has rated 323 items.
# After removing movies that have not been rated by the user, we have 314 items.
# User 901 has rated 119 items.
# After removing movies that have not been rated by the user, we have 116 items.
# User 479 has rated 200 items.
# After removing movies that have not been rated by the user, we have 190 items.
# User 65 has rated 78 items.
# After removing movies that have not been rated by the user, we have 78 items.
# User 416 has rated 487 items.
# After removing movies that have not been rated by the user, we have 10 items.
# User 1 has rated 269 items.
# After removing movies that have not been rated by the user, we have 231 items.
# User 406 has rated 336 items.
# After removing movies that have not been rated by the user, we have 333 items.
# User 291 has rated 293 items.
# After removing movies that have not been rated by the user, we have 265 items.
# User 747 has rated 292 items.
# After removing movies that have not been rated by the user, we have 282 items.
# User 577 has rated 187 items.
# After removing movies that have not been rated by the user, we have 77 items.
# User 911 has rated 95 items.
# After removing movies that have not been rated by the user, we have 49 items.
# User 934 has rated 169 items.
# After removing movies that have not been rated by the user, we have 156 items.
# User 385 has rated 277 items.
# After removing movies that have not been rated by the user, we have 240 items.
# User 474 has rated 323 items.
# After removing movies that have not been rated by the user, we have 311 items.
# User 933 has rated 183 items.
# After removing movies that have not been rated by the user, we have 182 items.
# User 269 has rated 319 items.
# After removing movies that have not been rated by the user, we have 308 items.
# User 123 has rated 53 items.
# After removing movies that have not been rated by the user, we have 52 items.
# User 716 has rated 268 items.
# After removing movies that have not been rated by the user, we have 266 items.
# User 868 has rated 205 items.
# After removing movies that have not been rated by the user, we have 203 items.
# User 313 has rated 255 items.
# After removing movies that have not been rated by the user, we have 253 items.
# User 331 has rated 69 items.
# After removing movies that have not been rated by the user, we have 64 items.
# User 89 has rated 72 items.
# After removing movies that have not been rated by the user, we have 72 items.
# User 862 has rated 162 items.
# After removing movies that have not been rated by the user, we have 154 items.
# User 206 has rated 62 items.
# After removing movies that have not been rated by the user, we have 51 items.
# User 8 has rated 58 items.
# After removing movies that have not been rated by the user, we have 57 items.
# User 180 has rated 61 items.
# After removing movies that have not been rated by the user, we have 61 items.
# User 805 has rated 268 items.
# After removing movies that have not been rated by the user, we have 266 items.
# User 184 has rated 248 items.
# After removing movies that have not been rated by the user, we have 227 items.
# User 556 has rated 43 items.
# After removing movies that have not been rated by the user, we have 42 items.
# User 218 has rated 51 items.
# After removing movies that have not been rated by the user, we have 51 items.
# User 452 has rated 204 items.
# After removing movies that have not been rated by the user, we have 199 items.
# User 781 has rated 41 items.
# After removing movies that have not been rated by the user, we have 39 items.
# User 280 has rated 252 items.
# After removing movies that have not been rated by the user, we have 235 items.
# User 424 has rated 42 items.
# After removing movies that have not been rated by the user, we have 40 items.
# User 416 has rated 487 items.
# After removing movies that have not been rated by the user, we have 466 items.
# User 886 has rated 238 items.
# After removing movies that have not been rated by the user, we have 230 items.
# User 494 has rated 46 items.
# After removing movies that have not been rated by the user, we have 46 items.
# User 83 has rated 152 items.
# After removing movies that have not been rated by the user, we have 150 items.
# User 791 has rated 23 items.
# After removing movies that have not been rated by the user, we have 23 items.
# User 128 has rated 183 items.
# After removing movies that have not been rated by the user, we have 182 items.
# User 851 has rated 207 items.
# After removing movies that have not been rated by the user, we have 189 items.
# User 327 has rated 282 items.
# After removing movies that have not been rated by the user, we have 251 items.
# User 493 has rated 133 items.
# After removing movies that have not been rated by the user, we have 129 items.
# User 287 has rated 60 items.
# After removing movies that have not been rated by the user, we have 60 items.
# User 305 has rated 220 items.
# After removing movies that have not been rated by the user, we have 212 items.
# User 917 has rated 34 items.
# After removing movies that have not been rated by the user, we have 34 items.
# User 311 has rated 291 items.
# After removing movies that have not been rated by the user, we have 290 items.
# User 104 has rated 110 items.
# After removing movies that have not been rated by the user, we have 109 items.
# User 655 has rated 677 items.
# After removing movies that have not been rated by the user, we have 386 items.
# User 606 has rated 231 items.
# After removing movies that have not been rated by the user, we have 223 items.
# User 932 has rated 237 items.
# After removing movies that have not been rated by the user, we have 198 items.
# User 611 has rated 40 items.
# After removing movies that have not been rated by the user, we have 29 items.
# User 889 has rated 323 items.
# After removing movies that have not been rated by the user, we have 306 items.
# User 453 has rated 155 items.
# After removing movies that have not been rated by the user, we have 155 items.
# User 14 has rated 96 items.
# After removing movies that have not been rated by the user, we have 94 items.
# User 279 has rated 431 items.
# After removing movies that have not been rated by the user, we have 126 items.
# User 532 has rated 272 items.
# After removing movies that have not been rated by the user, we have 222 items.
# User 437 has rated 258 items.
# After removing movies that have not been rated by the user, we have 252 items.
# User 487 has rated 228 items.
# After removing movies that have not been rated by the user, we have 209 items.
# User 450 has rated 534 items.
# After removing movies that have not been rated by the user, we have 374 items.
# User 672 has rated 28 items.
# After removing movies that have not been rated by the user, we have 25 items.
# User 630 has rated 105 items.
# After removing movies that have not been rated by the user, we have 104 items.
# User 176 has rated 62 items.
# After removing movies that have not been rated by the user, we have 61 items.
# User 429 has rated 410 items.
# After removing movies that have not been rated by the user, we have 403 items.
# User 640 has rated 108 items.
# After removing movies that have not been rated by the user, we have 106 items.
# User 312 has rated 222 items.
# After removing movies that have not been rated by the user, we have 215 items.
# User 83 has rated 152 items.
# After removing movies that have not been rated by the user, we have 140 items.
# User 82 has rated 165 items.
# After removing movies that have not been rated by the user, we have 159 items.
# User 174 has rated 172 items.
# After removing movies that have not been rated by the user, we have 135 items.
# User 796 has rated 352 items.
# After removing movies that have not been rated by the user, we have 347 items.
# User 1 has rated 269 items.
# After removing movies that have not been rated by the user, we have 250 items.
# User 887 has rated 168 items.
# After removing movies that have not been rated by the user, we have 146 items.
# User 854 has rated 213 items.
# After removing movies that have not been rated by the user, we have 208 items.
# User 157 has rated 50 items.
# After removing movies that have not been rated by the user, we have 49 items.
# User 440 has rated 50 items.
# After removing movies that have not been rated by the user, we have 0 items.
# User 393 has rated 444 items.
# After removing movies that have not been rated by the user, we have 423 items.
# User 116 has rated 141 items.
# After removing movies that have not been rated by the user, we have 137 items.
# User 56 has rated 182 items.
# After removing movies that have not been rated by the user, we have 182 items.
# User 391 has rated 118 items.
# After removing movies that have not been rated by the user, we have 118 items.
# User 870 has rated 265 items.
# After removing movies that have not been rated by the user, we have 260 items.
# User 561 has rated 353 items.
# After removing movies that have not been rated by the user, we have 346 items.
# User 454 has rated 232 items.
# After removing movies that have not been rated by the user, we have 229 items.
# User 341 has rated 19 items.
# After removing movies that have not been rated by the user, we have 18 items.
# User 269 has rated 319 items.
# After removing movies that have not been rated by the user, we have 308 items.
# User 295 has rated 194 items.
# After removing movies that have not been rated by the user, we have 190 items.
# User 276 has rated 509 items.
# After removing movies that have not been rated by the user, we have 227 items.
# User 592 has rated 357 items.
# After removing movies that have not been rated by the user, we have 305 items.
# User 543 has rated 194 items.
# After removing movies that have not been rated by the user, we have 183 items.
# User 79 has rated 53 items.
# After removing movies that have not been rated by the user, we have 53 items.
# User 862 has rated 162 items.
# After removing movies that have not been rated by the user, we have 162 items.
# User 222 has rated 382 items.
# After removing movies that have not been rated by the user, we have 374 items.
# User 625 has rated 104 items.
# After removing movies that have not been rated by the user, we have 104 items.
# User 523 has rated 99 items.
# After removing movies that have not been rated by the user, we have 96 items.
# User 877 has rated 80 items.
# After removing movies that have not been rated by the user, we have 79 items.
# User 276 has rated 509 items.
# After removing movies that have not been rated by the user, we have 281 items.
# User 783 has rated 29 items.
# After removing movies that have not been rated by the user, we have 29 items.
# User 806 has rated 138 items.
# After removing movies that have not been rated by the user, we have 138 items.
# User 624 has rated 139 items.
# After removing movies that have not been rated by the user, we have 136 items.
# User 852 has rated 48 items.
# After removing movies that have not been rated by the user, we have 48 items.
# User 345 has rated 230 items.
# After removing movies that have not been rated by the user, we have 223 items.
# User 874 has rated 32 items.
# After removing movies that have not been rated by the user, we have 32 items.
# User 268 has rated 327 items.
# After removing movies that have not been rated by the user, we have 324 items.
# User 421 has rated 61 items.
# After removing movies that have not been rated by the user, we have 60 items.
# User 924 has rated 81 items.
# After removing movies that have not been rated by the user, we have 80 items.
# User 868 has rated 205 items.
# After removing movies that have not been rated by the user, we have 170 items.
# User 729 has rated 20 items.
# After removing movies that have not been rated by the user, we have 13 items.
# User 790 has rated 228 items.
# After removing movies that have not been rated by the user, we have 226 items.
# User 194 has rated 301 items.
# After removing movies that have not been rated by the user, we have 292 items.
# User 699 has rated 147 items.
# After removing movies that have not been rated by the user, we have 140 items.
# User 13 has rated 634 items.
# After removing movies that have not been rated by the user, we have 50 items.
# User 798 has rated 236 items.
# After removing movies that have not been rated by the user, we have 178 items.
# User 711 has rated 218 items.
# After removing movies that have not been rated by the user, we have 14 items.
# User 521 has rated 148 items.
# After removing movies that have not been rated by the user, we have 147 items.
# User 726 has rated 23 items.
# After removing movies that have not been rated by the user, we have 23 items.
# User 450 has rated 534 items.
# After removing movies that have not been rated by the user, we have 495 items.
# User 561 has rated 353 items.
# After removing movies that have not been rated by the user, we have 345 items.
# User 707 has rated 235 items.
# After removing movies that have not been rated by the user, we have 187 items.
# User 272 has rated 50 items.
# After removing movies that have not been rated by the user, we have 49 items.
# User 383 has rated 69 items.
# After removing movies that have not been rated by the user, we have 69 items.
# User 778 has rated 64 items.
# After removing movies that have not been rated by the user, we have 63 items.
# User 293 has rated 386 items.
# After removing movies that have not been rated by the user, we have 375 items.
# Wall time: 39.6 s

# %%
test.head()
# Out:
#        user  movie  rating  pred
# 8548    276    282       4   3.0
# 6687    180    421       5   4.8
# 93118   308    121       3   3.2
# 31373   428    243       4   4.0
# 79953   487    301       4   4.4

# %%
test.shape
# Out:
# (999, 4)

# %%
# remove items that could not be rated
test = test.loc[test.pred != -1]

# %%
test.shape
# Out:
# (991, 4)

# %% [markdown]
# # Quality Metrics

# %%
rms = sqrt(mean_squared_error(test.rating, test.pred))
rms
# Out:
# 1.1086850967674038

# %%
stars = train.rating.value_counts(normalize=True)

# %%
# make random guesses of ratings, and compute RMSE as a basis for comparison
test['random'] = np.random.choice(stars.index, p=stars.values, size=test.shape[0])
test.head()
# Out:
#        user  movie  rating  pred  random
# 8548    276    282       4   3.0       3
# 6687    180    421       5   4.8       1
# 93118   308    121       3   3.2       5
# 31373   428    243       4   4.0       3
# 79953   487    301       4   4.4       4

# %%
random_rms = sqrt(mean_squared_error(test.rating, test.random))
random_rms
# Out:
# 1.5415535953662065
